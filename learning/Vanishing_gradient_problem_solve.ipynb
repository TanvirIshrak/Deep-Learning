# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.models import Sequential

# %%
x,y = make_moons(n_samples=250 , noise=0.005, random_state=42)

# %%
plt.scatter(x[:,0],x[:,1], c=y, s=100)
plt.show()

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=2))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Users\Tanvir Ishrak\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
old_weights = model.get_weights()[0] # stored first layer weight as old weight

# %%
x_train , x_test, y_train, y_test = train_test_split(
    x,y, test_size=0.2, random_state=42
)

# %%
model.fit(x_train,y_train, epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4900 - loss: 0.6803
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4900 - loss: 0.6715
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4900 - loss: 0.6627
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4900 - loss: 0.6488
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4900 - loss: 0.6297
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5150 - loss: 0.6078
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7400 - loss: 0.5838
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7850 - loss: 0.5652
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7850 - loss: 0.5544
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.5472
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8050 - loss: 0.5415
# Epoch 12/100
# ...

# %%
new_weights = model.get_weights()[0]

# %%
model.optimizer.get_config()['learning_rate']  # finding learning rate
# Out:
# 0.0010000000474974513

# %%
gradient = (old_weights - new_weights)/0.001
percent_change = abs(100*(old_weights - new_weights)/old_weights)

# %%
gradient
# Out:
# array([[-133.1613   , -121.183464 ,   20.66943  ,   16.613094 ,
#          -88.65898  , -108.837364 ,  -19.950151 ,    3.5216806,
#          229.89081  ,  246.21545  ],
#        [ -58.667065 , -125.33035  ,   49.45722  ,   71.70425  ,
#           84.01388  ,   98.75178  ,   54.23325  ,   99.171814 ,
#         -126.83802  , -145.43086  ]], dtype=float32)

# %%
percent_change
# Out:
# array([[ 28.831865 , 180.00348  ,   5.300737 ,   6.431496 ,  21.327417 ,
#          18.940462 ,   3.1370873,   1.1863097,  84.594795 , 109.231544 ],
#        [163.8473   ,  75.14312  ,  21.226376 ,  70.83041  ,  14.414175 ,
#          90.30073  ,   9.178454 ,  29.148975 ,  62.413063 ,  85.44495  ]],
#       dtype=float32)

# %%
old_weights
# Out:
# array([[ 0.46185464, -0.06732285,  0.38993508,  0.2583084 ,  0.4157043 ,
#          0.5746289 ,  0.635945  ,  0.29686016, -0.27175528, -0.22540691],
#        [-0.03580594,  0.16678888, -0.23299891, -0.10123372, -0.582856  ,
#         -0.10935879, -0.5908757 , -0.34022403, -0.20322353, -0.17020416]],
#       dtype=float32)

# %%
new_weights
# Out:
# array([[ 0.59501594,  0.05386062,  0.36926565,  0.24169531,  0.5043633 ,
#          0.68346626,  0.6558952 ,  0.29333848, -0.5016461 , -0.47162238],
#        [ 0.02286113,  0.29211923, -0.28245613, -0.17293797, -0.6668699 ,
#         -0.20811057, -0.64510894, -0.43939584, -0.0763855 , -0.02477329]],
#       dtype=float32)

# %%
model = Sequential()

# %% [markdown]
# We used 11layer dense layers and single or 250 epochs to train innitially but we saw loss got constant at 0.69

# %% [markdown]
# to solve this gradient decent problem i just minimise the layers to 3 used softmax and binary cross entropy and 200 epochs and witnessed the loss reduced to 0.49

# %% [markdown]
# 2nd rule to solve
# Use relu insteed of sigmoid , i makes -10 to 10 into 0 - 10
# If activation got 0 then derivative would be 0 that makes also constant loss it's called dying relu
# to solve this problem there is leaky relu
